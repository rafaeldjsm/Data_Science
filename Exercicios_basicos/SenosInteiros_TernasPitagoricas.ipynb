# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeldjsm/Data_Science_Raf/blob/master/Exercicios_basicos/SenosInteiros_TernasPitagoricas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Verificando os padrões nos senos dos números inteiros.

# %%
import plotly.express as px
from math import *

x = [*range(10000)]
y = [sin(k) for k in x]

fig = px.scatter(x=x,y=y)

fig.update_traces(marker=dict(size=1,
                              line=dict(width=2,
                                        color='blue')),
                  selector=dict(mode='markers'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3899f3d8-d13b-4a7c-88dd-ceae5a7b2c9d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3899f3d8-d13b-4a7c-88dd-ceae5a7b2c9d")) {
#                     Plotly.newPlot(
#                         '3899f3d8-d13b-4a7c-88dd-ceae5a7b2c9d',
# ...

# %% [markdown]
# # Espiral com aplicação de rotação de coordenadas

# %%
xl = [0]
yl = [0.1]

for k in range(500):
  x = xl[-1]*cos(91*pi/180) + yl[-1]*sin(91*pi/180)
  y = -xl[-1]*sin(91*pi/180) + yl[-1]*cos(91*pi/180)
  xl.append(x*1.05)
  yl.append(y*1.05)


fig = px.line(x=xl,y=yl)

fig.update_layout(
    width = 1000,
    height = 1000,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5b9d5b47-7312-4cdf-9653-b54b6a3bf9f8" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b9d5b47-7312-4cdf-9653-b54b6a3bf9f8")) {
#                     Plotly.newPlot(
#                         '5b9d5b47-7312-4cdf-9653-b54b6a3bf9f8',
# ...

# %% [markdown]
# # Verificando os padrões das Ternas Pitagóricas.

# %%
import plotly.graph_objects as go

n = int(input("Até qual limite deseja ver as ternas pitagóricas: "))


a = []
b = []

for k in range(1,n):
  for j in range(1,k):
    bt = (k**2-0 - j**2)**0.5
    if bt == int(bt):
      a.append(j)
      b.append(bt)


fig = px.scatter(x=a,y=b)

fig.update_layout(
    width = 1000,
    height = 1000,
)

fig.update_traces(marker=dict(size=1,
                              line=dict(width=2,
                                        color='blue')),
                  selector=dict(mode='markers'))

fig.show()
# Out:
# Até qual limite deseja ver as ternas pitagóricas: 10000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3410546c-9699-4391-9b74-54232bc44f6e" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3410546c-9699-4391-9b74-54232bc44f6e")) {
#                     Plotly.newPlot(
#                         '3410546c-9699-4391-9b74-54232bc44f6e',
# ...
