# %%
from PIL import Image
im = Image.open("luther.jpg")

# %%
print(im.format, im.size, im.mode)
# Out:
# JPEG (400, 244) RGB

# %%
colunas, linhas = im.size

# %%
im.getpixel((45,55))
# Out:
# (165, 161, 158)

# %%
for k in range(linhas):
    for j in range(colunas):
        r,g,b = im.getpixel((j,k))
        im.putpixel((j,k), (255-r,255-g,255-b))

# %%
im.save("test.jpg")

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
imgplot = plt.imshow(im)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
display(im)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x244 at 0x18A5CB1A760>

# %%
from IPython.display import Image
Image(filename='luther.jpg')
