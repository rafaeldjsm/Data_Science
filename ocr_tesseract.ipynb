# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaeldjsm/Data_Science/blob/master/ocr_tesseract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %%
import matplotlib.pyplot as plt
import cv2

# %%
im = cv2.imread("glebas.PNG", cv2.IMREAD_COLOR)

# %%
im = cv2.bitwise_not(im)
plt.imshow(im)
plt.show()

# %%
image_path_in_colab="glebas.PNG"
extract = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extract)
# Out:
# 7.305,74
# 8.072,12
# 8.066,65
# 8,067,62
# 8.480,82
# 8.377,48
# 8.553,57
# 8.845,22
# 9.109,17
# 9.155,87
# 9.357,77
# 9.521,95
#
# 17.888,04
# 17.896,30
# 17.808,46
# 17,710,72
# 18.307,99
# 18,378,72
# 18.709,60
# 19.019,74
# 19.139,38
# 19.237,42
# 19.538,68
# 19.957,56
#
# 7.097,24
# 7,098.41
# 7,102,26
# 7.091,78
# 7.252,94
# 7,209,711
# 7,232,385
# 7.147,66
# 7,170,30
# 7.312,49
# 7,522.21
# 7.580,95
#
# 1.318,52
# 1.317,97
# 1.310,66
# 1.299,76
# 1.320,52
# 1.327,07
# 1.370,77
# 1.370,62
# 1.375,17
# 1.378,30
# 1,382,21
# 1.386,56
#
# 5.931,32
# 5.949,17
# 6,003.93
# 5.928,40
# 5.995,64
# 6,073,312
#
# 6.213,96
# 6.302,66
# $467,680
# 6.462,24
# 6.516,48
# 6.551,29
#
# 3.533,89
# 3.531,16
# 3.494,62
# 3.440,12
# 3.468,36
# 3.501,11
#
# 3.719,58
# 3.718,83
# 3.741,57
# 3.757,24
# 3.776,80
# 3.798,54
#
# 16.677,29
# 16.738,17
# 16.521,26
# 16.023,21
# 16.100,22
# 16.374,53
# 16.799,90
# 16.797,02
# 17.107,67
# 17.160,09
# 17.268,05
# 17.500,01
#
# 9.072,46
# 9,064,27
# ...

# %%
extract=''.join(extract)

extract=extract.split('\n')

extract
# Out:
# ['7.305,74',
#  '8.072,12',
#  '8.066,65',
#  '8,067,62',
#  '8.480,82',
#  '8.377,48',
#  '8.553,57',
#  '8.845,22',
#  '9.109,17',
#  '9.155,87',
#  '9.357,77',
#  '9.521,95',
#  '',
#  '17.888,04',
#  '17.896,30',
#  '17.808,46',
#  '17,710,72',
#  '18.307,99',
#  '18,378,72',
#  '18.709,60',
#  '19.019,74',
#  '19.139,38',
#  '19.237,42',
#  '19.538,68',
#  '19.957,56',
#  '',
#  '7.097,24',
#  '7,098.41',
#  '7,102,26',
#  '7.091,78',
#  '7.252,94',
#  '7,209,711',
#  '7,232,385',
#  '7.147,66',
#  '7,170,30',
#  '7.312,49',
#  '7,522.21',
#  '7.580,95',
#  '',
#  '1.318,52',
#  '1.317,97',
#  '1.310,66',
#  '1.299,76',
#  '1.320,52',
#  '1.327,07',
#  '1.370,77',
#  '1.370,62',
#  '1.375,17',
#  '1.378,30',
#  '1,382,21',
#  '1.386,56',
#  '',
#  '5.931,32',
#  '5.949,17',
#  '6,003.93',
#  '5.928,40',
#  '5.995,64',
#  '6,073,312',
#  '',
#  '6.213,96',
#  '6.302,66',
#  '$467,680',
#  '6.462,24',
#  '6.516,48',
#  '6.551,29',
#  '',
#  '3.533,89',
#  '3.531,16',
# ...

# %%
lo = list()
li = []
for i in extract:
    if i!='' and i!=' ':
        li.append(i)
    else:
        if len(li) > 0:
            lo.append(li)
        li = []
lo
# Out:
# [['7.305,74',
#   '8.072,12',
#   '8.066,65',
#   '8,067,62',
#   '8.480,82',
#   '8.377,48',
#   '8.553,57',
#   '8.845,22',
#   '9.109,17',
#   '9.155,87',
#   '9.357,77',
#   '9.521,95'],
#  ['17.888,04',
#   '17.896,30',
#   '17.808,46',
#   '17,710,72',
#   '18.307,99',
#   '18,378,72',
#   '18.709,60',
#   '19.019,74',
#   '19.139,38',
#   '19.237,42',
#   '19.538,68',
#   '19.957,56'],
#  ['7.097,24',
#   '7,098.41',
#   '7,102,26',
#   '7.091,78',
#   '7.252,94',
#   '7,209,711',
#   '7,232,385',
#   '7.147,66',
#   '7,170,30',
#   '7.312,49',
#   '7,522.21',
#   '7.580,95'],
#  ['1.318,52',
#   '1.317,97',
#   '1.310,66',
#   '1.299,76',
#   '1.320,52',
#   '1.327,07',
#   '1.370,77',
#   '1.370,62',
#   '1.375,17',
#   '1.378,30',
#   '1,382,21',
#   '1.386,56'],
#  ['5.931,32', '5.949,17', '6,003.93', '5.928,40', '5.995,64', '6,073,312'],
#  ['6.213,96', '6.302,66', '$467,680', '6.462,24', '6.516,48', '6.551,29'],
# ...

# %%
df =pd.DataFrame(lo).T

# %%
df
# Out:
#           0          1          2         3          4         5         6   \
# 0   7.305,74  17.888,04   7.097,24  1.318,52   5.931,32  6.213,96  3.533,89
# 1   8.072,12  17.896,30   7,098.41  1.317,97   5.949,17  6.302,66  3.531,16
# 2   8.066,65  17.808,46   7,102,26  1.310,66   6,003.93  $467,680  3.494,62
# 3   8,067,62  17,710,72   7.091,78  1.299,76   5.928,40  6.462,24  3.440,12
# 4   8.480,82  18.307,99   7.252,94  1.320,52   5.995,64  6.516,48  3.468,36
# 5   8.377,48  18,378,72  7,209,711  1.327,07  6,073,312  6.551,29  3.501,11
# 6   8.553,57  18.709,60  7,232,385  1.370,77       None      None      None
# 7   8.845,22  19.019,74   7.147,66  1.370,62       None      None      None
# 8   9.109,17  19.139,38   7,170,30  1.375,17       None      None      None
# 9   9.155,87  19.237,42   7.312,49  1.378,30       None      None      None
# 10  9.357,77  19.538,68   7,522.21  1,382,21       None      None      None
# ...
